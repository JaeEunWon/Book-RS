# %% [markdown]
# # 아이템 기반 협업필터링
# - 주어진 평점 기반으로 아이템 간 유사도 계산 + 추천

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
Books = pd.read_csv('C://Users//dnjsw//Desktop//프로젝트//전처리//Books4.csv', encoding = 'utf-8')
Ratings = pd.read_csv('C://Users//dnjsw//Desktop//프로젝트//전처리//Ratings4.csv', encoding = 'utf-8')

# %%
bookrating = pd.merge(Books,Ratings, on='ISBN')
bookrating.drop(['Unnamed: 0_x','Unnamed: 0_y'], axis=1, inplace=True)
bookrating.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  1881320189                      Goodbye to the Buttermilk Sky
# 1  1841721522  New Vegetarian: Bold and Beautiful Recipes for...
# 2  1841721522  New Vegetarian: Bold and Beautiful Recipes for...
# 3  1841721522  New Vegetarian: Bold and Beautiful Recipes for...
# 4  1841721522  New Vegetarian: Bold and Beautiful Recipes for...
#
#           Book-Author  User-ID  Book-Rating
# 0        Julia Oliver   226745            7
# 1  Celia Brooks Brown     6366            7
# 2  Celia Brooks Brown   131126           10
# 3  Celia Brooks Brown   136633            9
# 4  Celia Brooks Brown   141518           10

# %%
bookrating1 = bookrating.pivot_table('Book-Rating', index = 'Book-Title', columns = 'User-ID').fillna(0)
bookrating1.head(2)
# Out:
# Book-Title   Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth  \
# User-ID
# 64                                                        0.0
# 70                                                        0.0
# 75                                                        0.0
# 92                                                        0.0
# 176                                                       0.0
#
# Book-Title   Final Fantasy Anthology: Official Strategy Guide (Brady Games)  \
# User-ID
# 64                                                        0.0
# 70                                                        0.0
# 75                                                        0.0
# 92                                                        0.0
# 176                                                       0.0
#
# Book-Title   Flight of Fancy: American Heiresses (Zebra Ballad Romance)  \
# User-ID
# ...

# %%
bookrating1.shape
# Out:
# (17955, 32414)

# %%
bookrating2 = bookrating.pivot_table('Book-Rating', index = 'Book-Title', columns = 'User-ID').fillna(0)
bookrating2.head(2)
# Out:
# User-ID                                             64      70      75      \
# Book-Title
#  Earth Prayers From around the World: 365 Praye...     0.0     0.0     0.0
#  Final Fantasy Anthology: Official Strategy Gui...     0.0     0.0     0.0
#
# User-ID                                             92      176     183     \
# Book-Title
#  Earth Prayers From around the World: 365 Praye...     0.0     0.0     0.0
#  Final Fantasy Anthology: Official Strategy Gui...     0.0     0.0     0.0
#
# User-ID                                             228     242     254     \
# Book-Title
#  Earth Prayers From around the World: 365 Praye...     0.0     0.0     0.0
#  Final Fantasy Anthology: Official Strategy Gui...     0.0     0.0     0.0
#
# User-ID                                             310     ...  278621  \
# Book-Title                                                  ...
#  Earth Prayers From around the World: 365 Praye...     0.0  ...     0.0
# ...

# %%
print(bookrating2.shape)
print(item_based_collabor.shape)
# Out:
# (32414, 17955)
# (32414, 32414)

# %%
item_based_collabor = cosine_similarity(bookrating2)

# %%
# 유사도 측정
item_based_collabor = pd.DataFrame(data = item_based_collabor, index = bookrating2.index, columns = bookrating2.index)
item_based_collabor.head()
# Out:
# Book-Title                                           Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth  \
# Book-Title
#  Earth Prayers From around the World: 365 Praye...                                                1.0
#  Final Fantasy Anthology: Official Strategy Gui...                                                0.0
#  Flight of Fancy: American Heiresses (Zebra Bal...                                                0.0
#  Little Comic Shop of Horrors (Give Yourself Go...                                                0.0
#  Q-Zone (Star Trek The Next Generation, Book 48)                                                  0.0
#
# Book-Title                                           Final Fantasy Anthology: Official Strategy Guide (Brady Games)  \
# Book-Title
#  Earth Prayers From around the World: 365 Praye...                                                0.0
# ...

# %%
def get_item(title):
    print('title : ',title)
    return pd.DataFrame(item_based_collabor[title].sort_values(ascending = False)[1:11])

# %%
get_item('#NAME?')
# Out:
# title :  #NAME?
#                                                       #NAME?
# Book-Title
# ESCANDALO DE ROLLOS MAR MUERTO                      0.752577
# Tolkien, J. R. R. - Una Biografia - Tapa Dur        0.752577
# La Escritura O La Vida                              0.752577
# Roverandom                                          0.752577
# Tumbas de Atuan, Las                                0.752577
# La Medicina Floral de Edward Bach                   0.752577
# Lescanya Pobres                                     0.616535
# Trajecte final (Col횂짢lecci횄쨀 universal de butxa...  0.594048
# El Juego del Reves                                  0.566372
# Nieve                                               0.495575
